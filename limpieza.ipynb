# %% [markdown]
# ![texto_descriptivo](portada.jpg)

# %% [markdown]
# ### Importamos los módulos necesarios para el proyecto

# %%
import pandas as pd
import src.limpieza_texto as lt

# %% [markdown]
# ### Cargamos el dataset

# %%
original_data = pd.read_csv("data/attacks.csv",encoding = "ISO-8859-1")

# %%
original_data.sample(5)
# Out:
#       Case Number         Date  Year        Type    Country  \
# 11572         NaN          NaN   NaN         NaN        NaN
# 8654            0          NaN   NaN         NaN        NaN
# 6769            0          NaN   NaN         NaN        NaN
# 6208      ND-0111  Before 1901   0.0  Unprovoked  SRI LANKA
# 18121         NaN          NaN   NaN         NaN        NaN
#
#                     Area Location  Activity  Name Sex   ... Species   \
# 11572                NaN      NaN       NaN   NaN  NaN  ...      NaN
# 8654                 NaN      NaN       NaN   NaN  NaN  ...      NaN
# 6769                 NaN      NaN       NaN   NaN  NaN  ...      NaN
# 6208   Northern Province   Mannar  Fishing?  male    M  ...      NaN
# 18121                NaN      NaN       NaN   NaN  NaN  ...      NaN
#
#       Investigator or Source                   pdf  \
# 11572                    NaN                   NaN
# 8654                     NaN                   NaN
# ...

# %% [markdown]
# There are some rows where there is no data.

# %%
original_data.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# ### The first step is to delete all the incomplete values.
# We use the function `dropna` to delete `all` the rows where there are no values.

# %%
data_filtered_1= original_data.dropna(axis=0, how="all")
print(data_filtered_1.shape)
data_filtered_1.tail()
# Out:
# (8703, 24)
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8698            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 8698   ...      NaN                    NaN  NaN          NaN  NaN
# 8699   ...      NaN                    NaN  NaN          NaN  NaN
# 8700   ...      NaN                    NaN  NaN          NaN  NaN
# 8701   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %% [markdown]
# As we cas see, there are some row where thr `case number` value is `0` and the rest of the values are `Nan`.
# First we create a new variable and select the filtered rows of the dataframe where the `case number`value is different from `0`.

# %%
data_filtered_2 = data_filtered_1[data_filtered_1["Case Number"] != "0"]
data_filtered_2.tail(5)
# Out:
#       Case Number         Date  Year        Type             Country  \
# 6298      ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299      ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300      ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301      ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# 25722          xx          NaN   NaN         NaN                 NaN
#
#                     Area                             Location      Activity  \
# 6298   Western Australia                                  NaN  Pearl diving
# 6299      North Carolina                       Ocracoke Inlet      Swimming
# 6300                 NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301    Eastern Province  Below the English fort, Trincomalee      Swimming
# 25722                NaN                                  NaN           NaN
#
#                         Name Sex   ... Species   \
# ...

# %% [markdown]
# As que can see, there is a value at the end of dataframe where the `Case Number` value is `xx` and the rest of the values of the row `NaN`, so I delete that row using the method `.drop()` and selecting the value of the index.

# %%
data_filtered_3 = data_filtered_2.drop(index= 25722)

# %%
data_filtered_3.sample(3)
# Out:
#        Case Number         Date    Year        Type       Country  \
# 2936    1983.06.20  20-Jun-1983  1983.0  Unprovoked           USA
# 3720  1963.12.22.a  22-Dec-1963  1963.0    Provoked  SOUTH AFRICA
# 2925  1983.08.13.a  13-Aug-1983  1983.0  Unprovoked           USA
#
#                Area                                         Location  \
# 2936        Florida                      Cocoa Beach, Brevard County
# 3720  KwaZulu-Natal               Next to West Street groyne, Durban
# 2925        Florida  6 miles south of Boca Chica Key, Monroe County
#
#                                             Activity              Name Sex   \
# 2936  Surfing & dangling foot in water amid baitfish     Barry Skinner    M
# 3720                Helping friend land hooked shark  Desmond Woodhams    M
# 2925                                          Diving       Jackie Lynn    F
#
#       ...             Species           Investigator or Source  \
# ...

# %% [markdown]
# There are also some columns called`pdf`, `href formula`, `Unnamed: 22`, `Unnamed: 23`, which I consider that are not useful.
#
# The column `original order` is also no usefull becouse is the same as the index but inverted.

# %%
data_filtered_4 = data_filtered_3.drop(["Unnamed: 22","Unnamed: 23", "pdf", "href formula", "original order"], axis=1)
data_filtered_4.sample(3)
# Out:
#        Case Number         Date    Year        Type    Country        Area  \
# 2410  1994.12.09.b  09-Dec-1994  1994.0     Invalid  AUSTRALIA  Queensland
# 2904    1984.02.11  11-Feb-1984  1984.0  Unprovoked  AUSTRALIA  Queensland
# 235   2016.07.28.R  28-Jul-2016  2016.0  Unprovoked      CHINA   Hong Kong
#
#                               Location       Activity           Name Sex  Age  \
# 2410  Hinchinbrook Channel, Queensland  Murder victim  Peter Saibura    M  44
# 2904                    Derwent Island   Spearfishing    Greg Pearce    M  27
# 235                                NaN       Swimming   Justus Franz    M  72
#
#                              Injury Fatal (Y/N) Time  \
# 2410  Shark scavenged on his corpse         NaN  NaN
# 2904                    Hand bitten           N  NaN
# 235              Lacerations to leg           N  NaN
#
#                            Species         Investigator or Source  \
# ...

# %% [markdown]
# #### At the end of the dataframe there are to columns, so the next step is to check if the information is difference between them.

# %%
data_filtered_4[data_filtered_4["Case Number.1"] != data_filtered_4["Case Number.2"]].sample(5)
# Out:
#        Case Number                                  Date    Year        Type  \
# 314   2016.01.24.b                           24-Jan-2016  2016.0  Unprovoked
# 5275  1900.00.00.R  Reported to have taken place in 1919  1919.0     Boating
# 144     2017.05.06                           05-May-2017  2017.0  Unprovoked
# 5386  1911.07.31.R                  Reported 31-Jul-1911  1911.0  Unprovoked
# 339   2015.10.28.a                           28-Oct-2015  2015.0  Unprovoked
#
#      Country                 Area                   Location       Activity  \
# 314      USA                Texas               Off Surfside   Spearfishing
# 5275   ITALY                  NaN                     Savona        Fishing
# 144   MEXICO  Baja California Sur  Los Arbolitos, Cabo Pulmo     Snorkeling
# 5386   SPAIN              Málaga                       Ceuta        Bathing
# 339      USA               Hawaii               Malaka, Oahu  Body boarding
#
#                  Name Sex   Age  \
# ...

# %% [markdown]
# After analyzing these two columns, you can see that it is the same value as the `case number` column but with different characters, so I decide to delete them.

# %%
data_filtered_5 = data_filtered_4.drop(["Case Number.1", "Case Number.2"], axis=1)
data_filtered_5.sample(3)
# Out:
#         Case Number         Date    Year        Type       Country  \
# 5704     1890.05.14  14-May-1890  1890.0     Invalid  SOUTH AFRICA
# 3942  1960.12.27.a.  27-Dec-1960  1960.0  Unprovoked     AUSTRALIA
# 3859   1962.00.00.c         1962  1962.0  Unprovoked         SPAIN
#
#                        Area             Location                    Activity  \
# 5704  Eastern Cape Province       Port Elizabeth                         NaN
# 3942        New South Wales  Bondi Beach, Sydney                         NaN
# 3859              Catalonia          Aigua Blava  Dangling feet in the water
#
#                               Name Sex   Age  \
# 5704                  Joseph Lundy    M  NaN
# 3942  Mrs. Despo Snow-Christensen     F   27
# 3859                        female    F  NaN
#
#                                                  Injury Fatal (Y/N) Time  \
# 5704  Forensic evidence indicated death resulted fro...         NaN  NaN
# ...

# %%
data_filtered_.corr()
# Out:
#       Year
# Year   1.0

# %% [markdown]
# I conducted a study on how many `researchers` there are and how much research they have carried out.

# %%
data_filtered_5["Investigator or Source"].unique()
# Out:
# array(['R. Collier, GSAF', 'K.McMurray, TrackingSharks.com',
#        'B. Myatt, GSAF', ..., 'F. Schwartz, p.23; C. Creswell, GSAF',
#        'The Sun, 10/20/1938', 'S.W. Baker'], dtype=object)

# %%
data_filtered_5["Investigator or Source"].value_counts()
# Out:
# C. Moore, GSAF                                               105
# C. Creswell, GSAF                                             92
# S. Petersohn, GSAF                                            82
# R. Collier                                                    55
# R. Collier, GSAF                                              48
#                                                             ...
# Coppleson (1962), p.247                                        1
# Geraldton Guardian, 6/18/1925                                  1
# V.M. Coppleson (1958), pp.67 & 233;  A. Sharpe, pp.89-90]      1
# Coppleson.V1. (1933); Melbourne Herald, 1/7/1925               1
# New Zealand Herald, 10/22/2017                                 1
# Name: Investigator or Source, Length: 4969, dtype: int64

# %%
data_filtered_5[data_filtered_5["Investigator or Source"] == "C. Moore, GSAF"].sample(10)
# Out:
#          Case Number                  Date    Year        Type     Country  \
# 5489      1905.08.24           24-Aug-1905  1905.0     Invalid       EGYPT
# 4467      1950.07.19            1950.07.19  1950.0    Provoked       ITALY
# 4826  1938.00.00.e.R         Reported 1938  1938.0  Unprovoked       EGYPT
# 5337      1914.06.12           13-Jun-1914  1914.0     Boating  MONTENEGRO
# 6148      1764.00.00                  1764  1764.0  Unprovoked       SPAIN
# 3810    1962.07.03.R  Reported 03-Jul-1962  1962.0     Invalid      GREECE
# 3513      1967.08.25           25-Aug-1967  1967.0  Unprovoked       ITALY
# 4949    1934.01.08.R  Reported 08-Feb-1934  1934.0     Boating      TURKEY
# 5939    1864.09.18.R  Reported 18-Sep-1864  1864.0    Provoked      FRANCE
# 5044    1930.05.11.R  Reported 11-May-1930  1930.0     Boating      TURKEY
#
#                 Area                        Location  \
# 5489      Suez Canal                       Port Said
# ...

# %%
import src.limpieza_texto as lt

# %%
lt.valores_iguales(data_filtered_5, "Investigator or Source", "C. Moore, GSAF")
# Out:
#        Case Number                  Date    Year        Type         Country  \
# 136   2017.06.07.R  Reported 07-Jun-2017  2017.0  Unprovoked  UNITED KINGDOM
# 2718  1988.08.22.a           22-Aug-1988  1988.0  Unprovoked           ITALY
# 3183  1976.06.02.R  Reported 02-Jun-1976  1976.0    Provoked           ITALY
# 3229    1975.04.25           25-Apr-1975  1975.0     Invalid           ITALY
# 3513    1967.08.25           25-Aug-1967  1967.0  Unprovoked           ITALY
# ...            ...                   ...     ...         ...             ...
# 6155    1742.12.17           17-Dec-1742  1742.0  Unprovoked             NaN
# 6156  1738.04.06.R  Reported 06-Apr-1738  1738.0  Unprovoked           ITALY
# 6193       ND-0134   Between   1951-1963     0.0  Unprovoked          GREECE
# 6196       ND-0130           Before 1876     0.0  Unprovoked         LEBANON
# 6197       ND-0129           Before 2012     0.0  Unprovoked           SPAIN
#
# ...

# %%
lt.funcioncita(2)
# Out:
# '4'

# %%
lt.elim_columnas()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-75f2e326aca6> in <module>
# ----> 1 lt.elim_columnas()
#
# TypeError: elim_columnas() missing 3 required positional arguments: 'df', 'lista', and 'new_name'

# %%
#exportamos el dataset a la carpeta data "midatasetlimpio.csv"
